# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\prani\OneDrive\Desktop\Minor Project\1 mini\DemographicData.csv')
data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
data.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
data.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
data['Birth rate'].sum()
# Out:
# 4186.6359999999995

# %%
x=data['Country Name'].head()
x
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Country Name, dtype: object

# %%
y=data['Internet users'].head()
y
# Out:
# 0    78.9
# 1     5.9
# 2    19.1
# 3    57.2
# 4    88.0
# Name: Internet users, dtype: float64

# %%
data.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
data.value_counts()
# Out:
# Country Name   Country Code  Birth rate  Internet users  Income Group
# Afghanistan    AFG           35.253      5.9000          Low income             1
# Samoa          WSM           26.172      15.3000         Lower middle income    1
# Nepal          NPL           20.923      13.3000         Low income             1
# Netherlands    NLD           10.200      93.9564         High income            1
# New Caledonia  NCL           17.000      66.0000         High income            1
#                                                                                ..
# Greece         GRC           8.500       59.8663         High income            1
# Greenland      GRL           14.500      65.8000         High income            1
# Grenada        GRD           19.334      35.0000         Upper middle income    1
# Guam           GUM           17.389      65.4000         High income            1
# Zimbabwe       ZWE           35.715      18.5000         Low income             1
# ...

# %% [markdown]
# # Matplotlib

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,marker='.',color='red',label='data')
plt.xlabel('Country Name')
plt.ylabel('Birth rate')
plt.title('Scatter Plot Of Birth rate of each Country')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Line Plot

# %%
plt.plot(x,y,marker='*',label='data')
plt.xlabel('Country Name')
plt.ylabel('Birth rate')
plt.title('Line plot of Birth rate of country name')
plt.legend()
plt.show()

# %% [markdown]
# # Bar Plot

# %%
plt.bar(x,y,color='Orange',label='data')
plt.xlabel('Country Name')
plt.ylabel('Birth rate')
plt.title('Bar plot of Birth rate of each Country')
plt.legend()
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.boxplot(data)
plt.xlabel('Data')
plt.ylabel('value')
plt.title('Boxplot')
plt.grid(True)
plt.show()

# %% [markdown]
# # Heat Map

# %%
plt.imshow(data,cmap='coolwarm',interpolation='nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %% [markdown]
# # Stacked Bar Plot

# %%
categories = ['A','B','C','D']
values1 =[20,13,54,23]
values2=[10,7,12,5]

plt.bar(categories,values1,color='Purple',label='Data1')
plt.bar(categories,values2,color='Yellow',label='Data2')
plt.xlabel=('Categories')
plt.ylabel=('Values')
plt.title('Stacked bar plot')
plt.legend()
plt.show()

# %% [markdown]
# # Violin Plot

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]
plt.violinplot(data,showmedians=True)
plt.xlabel('Distribution')
plt.ylabel('Value')
plt.title('Violin Plot')
plt.xticks(np.arange(1, len(data) +1),['Data1','Data2','Data3'])
plt.legend(['Median'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 data=[np.random.normal(0,std,100) for std in range(1,4)]
#       2 plt.violinplot(data,showmedians=True)
# ----> 3 plt.xlabel('Distribution')
#       4 plt.ylabel('Value')
#       5 plt.title('Violin Plot')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
data=pd.read_csv(r"C:\Users\prani\OneDrive\Desktop\Minor Project\1 mini\tips.csv")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
data['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.displot(data['day'])
# Out:
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(data['total_bill'])
# Out:
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(data['total_bill'],bins=10,kde=True)
plt.title('Histogram of Total_bills')
plt.show()
# Out:
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(x=data['total_bill'],color='Purple')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.scatterplot(x=data['total_bill'],y=data['tip'],color='orange')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x='total_bill',y='tip',data=data,hue='smoker')

# %%
sns.jointplot(x='total_bill',y='tip',data=data,color='blue')
# Out:
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(x='total_bill',y='day',data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.relplot(x='smoker',y='tip',kind='line',data=data)
# Out:
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df=sns.load_dataset("tips")
sns.pairplot(df)
# Out:
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\prani\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
